# %% [markdown]
# This is an Accenture Virtual Work Experience program , free for students and available through the forage website.
#
# 1st step - Data Cleaning.

# %%
import pandas as pd

content = pd.read_csv('Content.csv')
reaction=pd.read_csv('Reactions.csv')
reactiontypes = pd.read_csv('ReactionTypes.csv')

# %% [markdown]
# We have three datasets which contains the information about the business operations of a social media company. The tasks are:
# How many unique categories are there?
# How many reactions are there to the most popular category?
# What was the month with the most posts?
#
# There was initially 7 datasets, but since we were asked to obtain answers to the questions above, we only needed to specifically choose 3 datasets that would provide us with the answer. These datasets are imported above.
#
#
# But before visualization, we need to clean the data.

# %%
content
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
reaction
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# ...

# %%
reactiontypes
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %% [markdown]
# Step 1:
# 1 Remove all missing values or the empty rows and create a filtered table.

# %%
content.dropna()
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 994         994  c54b49c4-b1f2-4641-8595-1cbd19937845
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type        Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# ...

# %%
reaction.dropna()
# Out:
#        Unnamed: 0                            Content ID  \
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25547       25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# ...

# %% [markdown]
# Step 2:
# Delete unnecessary columns. Here we dont need the URL column

# %%
del content['URL']

# %%
content
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %% [markdown]
# Step 3:
# Check for the different types in the "Type" (Or "Content Type", this will be changed later down below) column in both the tables.

# %%
content['Type'].unique()
content['Category'].unique()
# Out:
# array(['Studying', 'healthy eating', 'technology', 'food', 'cooking',
#        'dogs', 'soccer', 'public speaking', 'science', 'tennis', 'travel',
#        'fitness', 'education', 'studying', 'veganism', 'Animals',
#        'animals', 'culture', '"culture"', 'Fitness', '"studying"',
#        'Veganism', '"animals"', 'Travel', '"soccer"', 'Education',
#        '"dogs"', 'Technology', 'Soccer', '"tennis"', 'Culture', '"food"',
#        'Food', '"technology"', 'Healthy Eating', '"cooking"', 'Science',
#        '"public speaking"', '"veganism"', 'Public Speaking', '"science"'],
#       dtype=object)

# %% [markdown]
# Code below automatically strips "" for all the strings in the column 'Category'. Hence this column had 41 unique values, but now it has only 29 unique values.

# %%
count=0
while count<=999:
   
   content['Category'].replace(content['Category'][count],content['Category'][count].strip('"'),inplace=True)
   count+=1

# %%
content['Category'].unique()
# Out:
# array(['Studying', 'healthy eating', 'technology', 'food', 'cooking',
#        'dogs', 'soccer', 'public speaking', 'science', 'tennis', 'travel',
#        'fitness', 'education', 'studying', 'veganism', 'Animals',
#        'animals', 'culture', 'Fitness', 'Veganism', 'Travel', 'Education',
#        'Technology', 'Soccer', 'Culture', 'Food', 'Healthy Eating',
#        'Science', 'Public Speaking'], dtype=object)

# %%
content
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
#no need for user id, since we are only checking for popularity of the content
content
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
content['Category'].unique()
# Out:
# array(['Studying', 'healthy eating', 'technology', 'food', 'cooking',
#        'dogs', 'soccer', 'public speaking', 'science', 'tennis', 'travel',
#        'fitness', 'education', 'studying', 'veganism', 'Animals',
#        'animals', 'culture', 'Fitness', 'Veganism', 'Travel', 'Education',
#        'Technology', 'Soccer', 'Culture', 'Food', 'Healthy Eating',
#        'Science', 'Public Speaking'], dtype=object)

# %%
count=0
while count<=999:
   
   content['Category'].replace(content['Category'][count],content['Category'][count].lower(),inplace=True)
   count+=1

# %% [markdown]
# We make all the contents in the 'Category' column lower case. Hence the unique values in the Category column reduces from 29 to 16.

# %%
content['Category'].nunique()
# Out:
# 16

# %%
del reaction['User ID']

# %%
reaction
# Out:
#        Unnamed: 0                            Content ID        Type  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2         NaN
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# ...           ...                                   ...         ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56  interested
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish
#
#                   Datetime
# 0      2021-04-22 15:17:15
# 1      2020-11-07 09:43:50
# 2      2021-06-17 12:22:51
# 3      2021-04-18 05:13:58
# ...

# %%
content.dropna(inplace=True)
content
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
reactiontypes
reactiontypes.rename(columns = {'Type':'Type_x'}, inplace = True)

# %%
content
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %% [markdown]
# Combining the reaction and content dataset using the inner join.

# %%
first_combine = pd.merge(reaction,content,on='Content ID',how='inner')

# %%
first_combine
# Out:
#        Unnamed: 0_x                            Content ID      Type_x  \
# 0                 0  97522e57-d9ab-4bd6-97bf-c24d952602d2         NaN
# 1                 1  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 2                 2  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 3                 3  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 4                 4  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# ...             ...                                   ...         ...
# 25548         25548  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike
# 25549         25549  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued
# 25550         25550  75d6b589-7fae-4a6d-b0d0-752845150e56  interested
# 25551         25551  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 25552         25552  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish
#
#                   Datetime  Unnamed: 0_y  \
# 0      2021-04-22 15:17:15             0
# ...

# %% [markdown]
# Now we take the remaining dataset and combine with the ones we already merged.

# %%
second_combine =pd.merge(first_combine,reactiontypes,on='Type_x',how='inner')

# %%
second_combine
# Out:
#        Unnamed: 0_x                            Content ID   Type_x  \
# 0                 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 1                 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 2                35  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 3                52  9f737e0a-3cdd-4d29-9d24-753f4e3be810  disgust
# 4                88  230c4e4d-70c3-461d-b42c-ec09396efb3f  disgust
# ...             ...                                   ...      ...
# 24568         25489  435007a5-6261-4d8b-b0a4-55fdc189754b    adore
# 24569         25491  435007a5-6261-4d8b-b0a4-55fdc189754b    adore
# 24570         25512  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
# 24571         25524  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
# 24572         25531  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
#
#                   Datetime  Unnamed: 0_y  \
# 0      2020-11-07 09:43:50             0
# 1      2021-01-06 19:13:01             0
# ...

# %%
second_combine
# Out:
#        Unnamed: 0_x                            Content ID   Type_x  \
# 0                 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 1                 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 2                35  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 3                52  9f737e0a-3cdd-4d29-9d24-753f4e3be810  disgust
# 4                88  230c4e4d-70c3-461d-b42c-ec09396efb3f  disgust
# ...             ...                                   ...      ...
# 24568         25489  435007a5-6261-4d8b-b0a4-55fdc189754b    adore
# 24569         25491  435007a5-6261-4d8b-b0a4-55fdc189754b    adore
# 24570         25512  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
# 24571         25524  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
# 24572         25531  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
#
#                   Datetime  Unnamed: 0_y  \
# 0      2020-11-07 09:43:50             0
# 1      2021-01-06 19:13:01             0
# ...

# %% [markdown]
# Final merged dataset.

# %%
second_combine['month'] = pd.DatetimeIndex(second_combine['Datetime']).month
second_combine
# Out:
#        Unnamed: 0_x                            Content ID   Type_x  \
# 0                 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 1                 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 2                35  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 3                52  9f737e0a-3cdd-4d29-9d24-753f4e3be810  disgust
# 4                88  230c4e4d-70c3-461d-b42c-ec09396efb3f  disgust
# ...             ...                                   ...      ...
# 24568         25489  435007a5-6261-4d8b-b0a4-55fdc189754b    adore
# 24569         25491  435007a5-6261-4d8b-b0a4-55fdc189754b    adore
# 24570         25512  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
# 24571         25524  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
# 24572         25531  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
#
#                   Datetime  Unnamed: 0_y  \
# 0      2020-11-07 09:43:50             0
# 1      2021-01-06 19:13:01             0
# ...

# %% [markdown]
# Using the combined table , we can now find the month which had the maximum viewership. As seen from the result below, the month of May had the maximum viewership.

# %%
second_combine['month'].value_counts()
# Out:
# 5     2138
# 1     2126
# 8     2114
# 12    2092
# 7     2070
# 10    2056
# 11    2034
# 9     2022
# 6     2021
# 3     2012
# 4     1974
# 2     1914
# Name: month, dtype: int64

# %% [markdown]
# The visualization was done in excel using pivot tables. This revealed that the animals category was the most watched category among all other categories. The company had a total of 16 content categories and the month of May had the highest viewership.

# %% [markdown]
# Visualization can be found in the repository amalprojects/amalprojects with the file name as "Accenture.pbix"
